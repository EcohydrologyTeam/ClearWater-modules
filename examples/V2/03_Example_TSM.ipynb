# %%
from clearwater_modules_v2.config import init_from_file
from pathlib import Path

config_path = Path(R"C:\Users\ptomasula\Repositories\ClearWater-modules\src\clearwater_modules_v2\dev.yml")
model = init_from_file(config_path)
model.run()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from clearwater_modules_v2.config import init_from_file
#       2 from pathlib import Path
#       4 config_path = Path(R"C:\Users\ptomasula\Repositories\ClearWater-modules\src\clearwater_modules_v2\dev.yml")
#
# File ~\Repositories\ClearWater-modules\src\clearwater_modules_v2\config\__init__.py:2
#       1 from .read import read_config
# ----> 2 from .init import init_from_file
#       3 from .example import main as export_example
#
# File ~\Repositories\ClearWater-modules\src\clearwater_modules_v2\config\init.py:1
# ----> 1 from model import Model
#       2 from processes.base import Process, ProcessFactory
#       3 from pathlib import Path
#
# ModuleNotFoundError: No module named 'model'

# %%
a = "prt"
